# %%
# %matplotlib inline

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
train_files = glob.glob('training_data\\*')

# %%
train_files[:10]
# Out:
# ['training_data\\cat.10003.jpg',
#  'training_data\\cat.10009.jpg',
#  'training_data\\cat.10013.jpg',
#  'training_data\\cat.10024.jpg',
#  'training_data\\cat.10026.jpg',
#  'training_data\\cat.10031.jpg',
#  'training_data\\cat.10033.jpg',
#  'training_data\\cat.10039.jpg',
#  'training_data\\cat.10041.jpg',
#  'training_data\\cat.1005.jpg']

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data\\*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)

#train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files] # for linux
train_labels = [fn.split('\\')[1].split('.')[0].strip() for fn in train_files] # for windows

validation_files = glob.glob('validation_data\\*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
#validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files] # for linux
validation_labels = [fn.split('\\')[1].split('.')[0].strip() for fn in validation_files] # for windows

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (4546, 150, 150, 3)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
# encode wine type labels
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[0:5], train_labels_enc[0:5])
# Out:
# ['cat', 'cat', 'cat', 'cat', 'cat'] [0 0 0 0 0]

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=30,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

# %%
#train_datagen

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 1200
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
img_id = 1991
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['dog', 'dog', 'dog', 'dog', 'dog']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=32)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=16)

input_shape = (150, 150, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', 
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,706,113
# Trainable params: 3,706,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_generator, steps_per_epoch=50, epochs=50,
                              validation_data=val_generator, validation_steps=50, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-18-1f895a3cd4b8>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 50/50 [==============================] - 29s 577ms/step - loss: 0.6942 - accuracy: 0.5025 - val_loss: 0.6904 - val_accuracy: 0.6037
# Epoch 2/50
# 50/50 [==============================] - 31s 618ms/step - loss: 0.6901 - accuracy: 0.5319 - val_loss: 0.6877 - val_accuracy: 0.5138
# Epoch 3/50
# 50/50 [==============================] - 30s 600ms/step - loss: 0.6828 - accuracy: 0.5653 - val_loss: 0.6679 - val_accuracy: 0.5750
# Epoch 4/50
# 50/50 [==============================] - 31s 617ms/step - loss: 0.6784 - accuracy: 0.5600 - val_loss: 0.6702 - val_accuracy: 0.5400
# Epoch 5/50
# 50/50 [==============================] - 30s 596ms/step - loss: 0.6692 - accuracy: 0.5810 - val_loss: 0.6382 - val_accuracy: 0.6363
# Epoch 6/50
# 50/50 [==============================] - 30s 601ms/step - loss: 0.6682 - accuracy: 0.5831 - val_loss: 0.6493 - val_accuracy: 0.5913
# Epoch 7/50
# 50/50 [==============================] - 30s 607ms/step - loss: 0.6598 - accuracy: 0.5923 - val_loss: 0.6482 - val_accuracy: 0.6050
# Epoch 8/50
# 50/50 [==============================] - 31s 613ms/step - loss: 0.6510 - accuracy: 0.6162 - val_loss: 0.6324 - val_accuracy: 0.6225
# Epoch 9/50
# 50/50 [==============================] - 30s 604ms/step - loss: 0.6507 - accuracy: 0.6099 - val_loss: 0.6281 - val_accuracy: 0.6275
# Epoch 10/50
# 50/50 [==============================] - 30s 593ms/step - loss: 0.6384 - accuracy: 0.6024 - val_loss: 0.6196 - val_accuracy: 0.6587
# Epoch 11/50
# 50/50 [==============================] - 30s 598ms/step - loss: 0.6348 - accuracy: 0.6225 - val_loss: 0.6269 - val_accuracy: 0.6562
# Epoch 12/50
# 50/50 [==============================] - 30s 599ms/step - loss: 0.6272 - accuracy: 0.6375 - val_loss: 0.6853 - val_accuracy: 0.5537
# Epoch 13/50
# 50/50 [==============================] - 30s 606ms/step - loss: 0.6247 - accuracy: 0.6300 - val_loss: 0.6178 - val_accuracy: 0.6500
# Epoch 14/50
# 50/50 [==============================] - 30s 608ms/step - loss: 0.6157 - accuracy: 0.6544 - val_loss: 0.6159 - val_accuracy: 0.6625
# Epoch 15/50
# 50/50 [==============================] - 30s 602ms/step - loss: 0.6169 - accuracy: 0.6539 - val_loss: 0.7146 - val_accuracy: 0.5362
# Epoch 16/50
# 50/50 [==============================] - 31s 621ms/step - loss: 0.6110 - accuracy: 0.6694 - val_loss: 0.6388 - val_accuracy: 0.6137
# Epoch 17/50
# 50/50 [==============================] - 31s 623ms/step - loss: 0.6119 - accuracy: 0.6694 - val_loss: 0.5681 - val_accuracy: 0.7063
# Epoch 18/50
# 50/50 [==============================] - 33s 663ms/step - loss: 0.6022 - accuracy: 0.6675 - val_loss: 0.6501 - val_accuracy: 0.6338
# Epoch 19/50
# 50/50 [==============================] - 31s 616ms/step - loss: 0.5845 - accuracy: 0.6819 - val_loss: 0.5819 - val_accuracy: 0.7000
# Epoch 20/50
# 50/50 [==============================] - 31s 617ms/step - loss: 0.5856 - accuracy: 0.6866 - val_loss: 0.5953 - val_accuracy: 0.6837
# Epoch 21/50
# 50/50 [==============================] - 30s 601ms/step - loss: 0.5790 - accuracy: 0.6947 - val_loss: 0.5614 - val_accuracy: 0.6862
# Epoch 22/50
# 50/50 [==============================] - 30s 601ms/step - loss: 0.5765 - accuracy: 0.6884 - val_loss: 0.5771 - val_accuracy: 0.6625
# Epoch 23/50
# 50/50 [==============================] - 30s 606ms/step - loss: 0.5790 - accuracy: 0.6731 - val_loss: 0.6457 - val_accuracy: 0.6388
# Epoch 24/50
# 50/50 [==============================] - 31s 613ms/step - loss: 0.5797 - accuracy: 0.7013 - val_loss: 0.5328 - val_accuracy: 0.7337
# Epoch 25/50
# 50/50 [==============================] - 30s 599ms/step - loss: 0.5770 - accuracy: 0.6834 - val_loss: 0.5448 - val_accuracy: 0.7262
# Epoch 26/50
# 50/50 [==============================] - 31s 615ms/step - loss: 0.5772 - accuracy: 0.6862 - val_loss: 0.5476 - val_accuracy: 0.7138
# Epoch 27/50
# 50/50 [==============================] - 31s 612ms/step - loss: 0.5581 - accuracy: 0.7136 - val_loss: 0.5612 - val_accuracy: 0.7000
# Epoch 28/50
# 50/50 [==============================] - 31s 620ms/step - loss: 0.5539 - accuracy: 0.7269 - val_loss: 0.5463 - val_accuracy: 0.7262
# Epoch 29/50
# 50/50 [==============================] - 33s 651ms/step - loss: 0.5615 - accuracy: 0.6975 - val_loss: 0.5331 - val_accuracy: 0.7312
# Epoch 30/50
# 50/50 [==============================] - 30s 604ms/step - loss: 0.5775 - accuracy: 0.6925 - val_loss: 0.6051 - val_accuracy: 0.6725
# Epoch 31/50
# 50/50 [==============================] - 30s 608ms/step - loss: 0.5636 - accuracy: 0.6981 - val_loss: 0.5840 - val_accuracy: 0.7138
# Epoch 32/50
# 50/50 [==============================] - 30s 606ms/step - loss: 0.5550 - accuracy: 0.7230 - val_loss: 0.5074 - val_accuracy: 0.7625
# Epoch 33/50
# 50/50 [==============================] - 31s 619ms/step - loss: 0.5518 - accuracy: 0.7200 - val_loss: 0.5147 - val_accuracy: 0.7337
# Epoch 34/50
# 50/50 [==============================] - 36s 719ms/step - loss: 0.5518 - accuracy: 0.7085 - val_loss: 0.5334 - val_accuracy: 0.7387
# Epoch 35/50
# 50/50 [==============================] - 62s 1s/step - loss: 0.5491 - accuracy: 0.7138 - val_loss: 0.5387 - val_accuracy: 0.7262
# Epoch 36/50
# 50/50 [==============================] - 63s 1s/step - loss: 0.5575 - accuracy: 0.7144 - val_loss: 0.4876 - val_accuracy: 0.7700
# Epoch 37/50
# 50/50 [==============================] - 63s 1s/step - loss: 0.5579 - accuracy: 0.7104 - val_loss: 0.5388 - val_accuracy: 0.7312
# Epoch 38/50
# 50/50 [==============================] - 61s 1s/step - loss: 0.5509 - accuracy: 0.7098 - val_loss: 0.5135 - val_accuracy: 0.7575
# Epoch 39/50
# 50/50 [==============================] - 59s 1s/step - loss: 0.5288 - accuracy: 0.7356 - val_loss: 0.5858 - val_accuracy: 0.6850
# Epoch 40/50
# 50/50 [==============================] - 62s 1s/step - loss: 0.5448 - accuracy: 0.7261 - val_loss: 0.5046 - val_accuracy: 0.7625
# Epoch 41/50
# 50/50 [==============================] - 62s 1s/step - loss: 0.5322 - accuracy: 0.7300 - val_loss: 0.5263 - val_accuracy: 0.7237
# Epoch 42/50
# 50/50 [==============================] - 61s 1s/step - loss: 0.5448 - accuracy: 0.7186 - val_loss: 0.5442 - val_accuracy: 0.7400
# Epoch 43/50
# 50/50 [==============================] - 61s 1s/step - loss: 0.5210 - accuracy: 0.7437 - val_loss: 0.5099 - val_accuracy: 0.7400
# Epoch 44/50
# 50/50 [==============================] - 62s 1s/step - loss: 0.5401 - accuracy: 0.7100 - val_loss: 0.5382 - val_accuracy: 0.7275
# Epoch 45/50
# 50/50 [==============================] - 63s 1s/step - loss: 0.5386 - accuracy: 0.7186 - val_loss: 0.5434 - val_accuracy: 0.7350
# Epoch 46/50
# 50/50 [==============================] - 66s 1s/step - loss: 0.5373 - accuracy: 0.7225 - val_loss: 0.5241 - val_accuracy: 0.7550
# Epoch 47/50
# 50/50 [==============================] - 63s 1s/step - loss: 0.5410 - accuracy: 0.7180 - val_loss: 0.5592 - val_accuracy: 0.7163
# Epoch 48/50
# 50/50 [==============================] - 63s 1s/step - loss: 0.5195 - accuracy: 0.7513 - val_loss: 0.4727 - val_accuracy: 0.7700
# Epoch 49/50
# 50/50 [==============================] - 46s 910ms/step - loss: 0.5063 - accuracy: 0.7563 - val_loss: 0.4746 - val_accuracy: 0.7825
# Epoch 50/50
# 50/50 [==============================] - 29s 586ms/step - loss: 0.4930 - accuracy: 0.7481 - val_loss: 0.4946 - val_accuracy: 0.7600

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('CNN with Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,51))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 51, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 51, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('12-09_aug_cnn.h5')
